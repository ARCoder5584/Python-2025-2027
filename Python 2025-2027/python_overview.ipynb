# %%
# Variables

# %%
import pandas as pd

df = pd.DataFrame({
    "employee": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank"],
    "age": [25, 30, 28, 35, 22, 40],
    "salary": [50000, 60000, 55000, 75000, 48000, 80000]
})

df["salary"]
