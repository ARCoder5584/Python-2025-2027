# %%
#Static data type in python
a=20
name="Alice"
Salary=20000
print("my name is",name)
print("my age is",a)
print("my salary is",Salary)
input(b"enter your name:")
input(b"enter your age:")
input(b"enter your salary:")
print("my name is",name)
print("my age is",a)
print("my salary is",Salary)

# %%
#Dynamic data type in python
name=str(input("enter your name:"))
a=int(input("enter your age:"))
Salary=float(input("enter your salary:"))
print("my name is",name)
print("my age is",a)
print("my salary is",Salary)
# Out:
# my name is Rashed
# my age is 20
# my salary is 20000.0

# %%
# 1 Addition of 2 numbers using dynamic data type
a=int(input("enter first number:"))
b=int(input("enter second number:"))
c=a+b
print("the sum is",c)
# Out:
# the sum is 30

# %%
#2 Addition of first name and last name using dynamic data type
f=str(input("enter your first name:"))
l=str(input("enter your last name:"))
c=f+l
print("your full name is",c)
# Out:
# your full name is ar

# %%
#3 Addition of 2 Float numbers using dynamic data type
x=float(input("enter first float number:"))
y=float(input("enter second float number:"))
z=x+y
print("the sum of float numbers is",z)
# Out:
# the sum of float numbers is 31.200000000000003
