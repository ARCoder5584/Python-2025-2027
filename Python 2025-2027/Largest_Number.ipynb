# %%
a = int(input("enter your 1st number: "))
b = int(input("enter your 2nd number: "))
c = int(input("enter your 3rd number: "))

if (a==b==c):
    print("All three numbers are equal:", a)
elif a>=b and a>=c:
    if a==b:
        print("1st and 2nd numbers are equal and largest:", a)
    elif a==c:
        print("1st and 3rd numbers are equal and largest:", a)
    else:
        print("1st number is largest:", a)
elif b>=a and b>=c:
    if b==a:
        print("1st and 2nd numbers are equal and largest:", b)
    elif b==c:
        print("2nd and 3rd numbers are equal and largest:", b)
    else:
        print("2nd number is largest:", b)
else:
    if (c==a):
        print("1st and 3rd numbers are equal and largest:", c)
    elif (c==b):
        print("2nd and 3rd numbers are equal and largest:", c)
    else:
        print("3rd number is largest:", c)
# Out:
# All three numbers are equal: 2
