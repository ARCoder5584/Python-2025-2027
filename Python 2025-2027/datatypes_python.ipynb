# %%
#Datatypes in Python
#Python have 3 main datatypes
#1. Integer
#2. Float
#3. String

# %%
a=10
b=20.5
c="Hello World"
print(a)
print(b)   
print(c)
print(type(a))
print(type(b)) 
print(type(c))
# Out:
# 10
# 20.5
# Hello World
# <class 'int'>
# <class 'float'>
# <class 'str'>
