# %%
while True:
    
    a = int(input("Enter your 1st number: "))
    b = int(input("Enter your 2nd number: "))
    d = str(input("Enter 'y' for continuation or 'n' for exiting: "))

    if d == 'n':
        print("Exiting....")
        break
    elif d == 'y':
        #for i in range(7):
            c = int(input("Enter 1 for Addition\n2 for Subtraction\n3 for Multiplication\n4 for Division\n5 for Modulus\n6 for Exponent\n7 for Floor Division\n8 for Exit\nEnter choice: "))
           # i += 1

            if c == 1:
                print("Addition:", a + b)
            elif c == 2:
                print("Subtraction:", a - b)
            elif c == 3:
                print("Multiplication:", a * b)
            elif c == 4:
                if b == 0:
                    print("Error: Division by zero!")
                else:
                    print("Division:", a / b)
            elif c == 5:
                if b == 0:
                    print("Error: Modulus by zero!")
                else:
                    print("Modulus:", a % b)
            elif c == 6:
                print("Exponent:", a ** b)
            elif c == 7:
                if b == 0:
                    print("Error: Floor division by zero!")
                else:
                    print("Floor Division:", a // b)
            elif c == 8:
                print("Exiting current operation...")
                break
            else:
                print("Invalid choice, try again.")
        #break
    else:
        print("Wrong Input, try again")
# Out:
# Subtraction: -1
# Exiting....
