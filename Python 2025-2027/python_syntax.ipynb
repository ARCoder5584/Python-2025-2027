# %%
# Variables- variable is a memory location to a value
name="John wick"
age=35
salary=5000000
print(name)
print(age)
print(salary)
# Out:
# John wick
# 35
# 5000000

# %%
# define variables following points
# 1. variable name does not start with a number
# 2. variable name does not contain special characters except _ (underscore)
# 3. variable name does not keywords (reserved words in python) like if, else, for, while, def, return etc

# %%
name1="John wick"
print(name1)
# Out:
# John wick

# %%
#display keywords in python
import keyword
print(keyword.kwlist)
keywords=keyword.kwlist
print(len(keywords))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
full_name="John wick"
print(full_name)
# Out:
# John wick
